# %% [markdown]
# #api do bacen
# https://dadosabertos.bcb.gov.br/dataset?res_format=API

# %%
import requests
import pprint as pr
import pandas as pd

# %%
link = "https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=100&$orderby=Data%20desc&$format=json"
requisicao = requests.get(link)
infos = requisicao.json()
#pr.pprint(infos)

# %%
tabela = pd.DataFrame(infos["value"])

# %%
#tabela["Quantidade"] = tabela["Quantidade"].map("{:,.2f}".format)
tabela["Valor"] = tabela["Valor"].map("{:,}".format)

# %%
display(tabela)
# Out:
#           Data  Quantidade              Valor Denominacao  Especie
# 0   2024-02-20  3191004939      31,910,049.39        0.01   Moedas
# 1   2024-02-20  7914316521     395,715,826.05        0.05   Moedas
# 2   2024-02-20  8072634915      807,263,491.5        0.10   Moedas
# 3   2024-02-20  3626385159     906,596,289.75        0.25   Moedas
# 4   2024-02-20  3658826862    1,829,413,431.0        0.50   Moedas
# ..         ...         ...                ...         ...      ...
# 95  2024-02-08  1738556873   86,927,843,650.0       50.00  Cédulas
# 96  2024-02-08  1871578734  187,157,873,400.0      100.00  Cédulas
# 97  2024-02-08   138172030   27,634,406,000.0      200.00  Cédulas
# 98  2024-02-07  3191004939      31,910,049.39        0.01   Moedas
# 99  2024-02-07  7907357537     395,367,876.85        0.05   Moedas
#
# [100 rows x 5 columns]
