# %%
import tabula
import PyPDF2

# %%
pdf_tabela = tabula.read_pdf("polonia.pdf", pages = "all")
# Out:
# Got stderr: fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES: Your current java version is: 1.8.0_181
# fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES: To get higher rendering speed on old java 1.8 or 9 versions,
# fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   or
# fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# fev 24, 2024 9:05:53 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFORMAÇÕES:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
for tabela in pdf_tabela:
    display(tabela)
# Out:
#              Origem: Wikipédia, a enciclopédia livre.  \
# 0   Polónia (português europeu) ou Polônia (português
# 1             brasileiro) (em polonês/polaco: Polska,
# 2                pronunciado: [ˈpɔlska] ( escutar )),
# 3               oficialmente República da Polónia (em
# 4              polonês/polaco: Rzeczpospolita Polska,
# 5             pronunciado: [ʐɛt͡ʂpɔˈspɔʎita̪ ˈpɔlska]
# 6       ( escutar )), é um país da Europa Central que
# 7       tem fronteiras comuns com a Alemanha a oeste;
# 8          com a Chéquia e a Eslováquia ao sul; com a
# 9         Ucrânia e a Bielorrússia a leste; com o Mar
# 10      Báltico, o Oblast de Kaliningrado (um exclave
# 11                                                NaN
# 12      russo) e a Lituânia ao norte. A área total da
# 13        nação é 312 679 quilômetros quadrados,[5] o
# 14     que a torna o 69.o maior país do mundo e o 9.o
#
#                              Unnamed: 0
# 0                                   NaN
# 1                                   NaN
# 2        República da Polónia / Polônia
# 3                 Rzeczpospolita Polska
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11             Bandeira Brasão de armas
# 12                                  NaN
# 13  Hino nacional: Mazurek Dąbrowskiego
# 14             ("Mazurca de Dąbrowski")
#                                          alemães (152       897    segundo  \
# 0   Opole e Silésia), bielorrussos (c. 49 000), uc...       NaN        NaN
# 1                                   lituanos, russos,  ciganos,    judeus,
# 2   tártaros poloneses. Entre os cidadãos estrange...       NaN        NaN
# 3   são o maior grupo étnico, seguido pelos gregos...       NaN        NaN
# 4   A língua polonesa, que faz parte do ramo ocide...       NaN        NaN
# 5   Até poucas décadas atrás, o russo era comument...       NaN        NaN
# 6   pelo inglês e alemão como segundas línguas mai...       NaN        NaN
# 7                                            Religião       NaN        NaN
# 8                                       Até a Segunda    Guerra   Mundial,
# 9   sociedade religiosamente diversa, na qual grup...       NaN        NaN
# 10                                                NaN       NaN        NaN
# 11                           ortodoxos, protestantes,       NaN  católicos
# 12                           substanciais coexistiam.       NaN       [36]
# 13  Polonesa, o catolicismo romano era a religião ...       NaN        NaN
# 14                                      declarado por     cerca     de 65%
# 15  seguido de outras denominações cristãs e cerca...       NaN        NaN
# 16  crentes no judaísmo.[37] Como resultado do Hol...       NaN        NaN
#
#       o        censo,  92%         dos quais                 vivem   em  \
# 0   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 1   NaN       lemkos,  NaN  eslovacos,   NaN               tchecos    e
# 2   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 3   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 4   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 5   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 6   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 7   NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 8   NaN     a Polônia  NaN         era   uma                   NaN  NaN
# 9   NaN           NaN  NaN         NaN   NaN              Religião  NaN
# 10  NaN           NaN  NaN         NaN   NaN           Catolicismo  NaN
# 11  NaN       romanos  NaN  e judaicos   NaN                   NaN  NaN
# 12   Na       Segunda  NaN   República   NaN  Sem religião Ateísmo  NaN
# 13  NaN           NaN  NaN         NaN   NaN           Ortodoxismo  NaN
# 14  NaN  dos cidadãos  NaN    polacos,   NaN                Outros  NaN
# 15  NaN           NaN  NaN         NaN   NaN                   NaN  NaN
# 16  NaN           NaN  NaN         NaN   NaN                   NaN  NaN
#
#                    Unnamed: 0 Unnamed: 1
# 0                         NaN        NaN
# 1                         NaN        NaN
# 2   Traje tradicional polonês        NaN
# 3                         NaN        NaN
# 4                         NaN        NaN
# 5                         NaN        NaN
# 6                         NaN        NaN
# 7                         NaN        NaN
# 8         Religião na Polónia        NaN
# 9                 Percentagem        NaN
# 10                        NaN        91%
# 11                        NaN        NaN
# 12                        NaN       3%2%
# 13                        NaN         1%
# 14                        NaN         2%
# 15                        NaN        NaN
# 16                        NaN        NaN
#        Unnamed: 0       Voivodia           Unnamed: 1
# 0             NaN            NaN  Capital ou capitais
# 1             NaN      em polaco                  NaN
# 2        Cujávia-      Kujawsko-                  NaN
# 3             NaN            NaN    Bydgoszcz / Toruń
# 4       Pomerânia      Pomorskie                  NaN
# 5          Grande            NaN                  NaN
# 6             NaN  Wielkopolskie               Poznań
# 7         Polónia            NaN                  NaN
# 8         Pequena            NaN                  NaN
# 9             NaN    Małopolskie             Cracóvia
# 10        Polónia            NaN                  NaN
# 11           Lodz        Łódzkie                 Lodz
# 12  Baixa Silésia   Dolnośląskie            Breslávia
# 13         Lublin      Lubelskie               Lublin
# 14            NaN            NaN               Gorzów
# 15      Lubúsquia       Lubuskie       Wielkopolski /
# 16            NaN            NaN         Zielona Góra
#         Mazóvia         Mazowieckie Varsóvia (Capital
# 0           NaN                 NaN         nacional)
# 1         Opole            Opolskie             Opole
# 2     Podláquia           Podlaskie         Białystok
# 3     Pomerânia           Pomorskie            Gdansk
# 4       Silésia             Śląskie          Katowice
# 5   Subcarpácia        Podkarpackie           Rzeszów
# 6    Santa Cruz      Świętokrzyskie            Kielce
# 7       Vármia-          Warmińsko-               NaN
# 8           NaN                 NaN           Olsztyn
# 9       Masúria           Mazurskie               NaN
# 10    Pomerânia                 NaN               NaN
# 11          NaN  Zachodniopomorskie          Estetino
# 12    Ocidental                 NaN               NaN
#                 Unnamed: 0              Nome em            Unnamed: 1  \
# 0                     Data                  NaN            Nome local
# 1                      NaN            português                   NaN
# 2                     1 de                  NaN                   NaN
# 3                      NaN             Ano Novo              Nowy Rok
# 4                  janeiro                  NaN                   NaN
# 5                     6 de                  NaN                   NaN
# 6                      NaN             Epifania   Święto Trzech Króli
# 7                  janeiro                  NaN                   NaN
# 8                      NaN               Páscoa    Święta Wielkanocne
# 9                1 de maio   Dia do Trabalhador          Święto Pracy
# 10                     NaN                  NaN  Święto Konstytucji 3
# 11               3 de maio  Dia da Constituição                   NaN
# 12                     NaN                  NaN                  Maja
# 13                     NaN                  NaN        Zesłania Ducha
# 14                     NaN          Pentecostes    Świętego - Zielone
# 15                     NaN                  NaN               Świątki
# 16                     NaN       Corpus Christi                   NaN
# 17                     NaN                  NaN            Boże Ciało
# 18                     NaN      (Corpo de Deus)                   NaN
# 19                     NaN                  NaN         Wniebowzięcie
# 20                     NaN    Assunção de Nossa                   NaN
# 21                   15 de                  NaN    Najświętszej Marii
# 22                     NaN    Senhora e Dia das                   NaN
# 23                  agosto                  NaN  Panny, Święto Wojska
# 24                     NaN       Forças Armadas                   NaN
# 25                     NaN                  NaN             Polskiego
# 26                    1 de      Dia de Todos os      Dzień Wszystkich
# 27         novembro Santos                  NaN              Świętych
# 28                   11 de               Dia da                   NaN
# 29                     NaN                  NaN  Dzień Niepodległości
# 30  novembro Independência                  NaN                   NaN
# 31                 25 e 26                  NaN                   NaN
# 32                      de                Natal       Boże Narodzenie
# 33                dezembro                  NaN                   NaN
#
#                         Unnamed: 2
# 0                      Observações
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8       Domigo e Segunda de Páscoa
# 9                              NaN
# 10  Comemoração da Constituição de
# 11                             NaN
# 12               3 de Maio de 1791
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20  O Dia das Forças Armadas serve
# 21                             NaN
# 22   como recordação da guerra com
# 23                             NaN
# 24         os bolcheviques em 1920
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28       Em 1918, após 123 anos de
# 29                             NaN
# 30                    inexistência
# 31                             NaN
# 32                             NaN
# 33                             NaN

# %%
arquivo_pdf = open("polonia.pdf","rb")

# %%
pdf = PyPDF2.PdfReader(arquivo_pdf)

# %%
len(pdf.pages)
# Out:
# 22

# %%
pagina =  pdf.pages[0]

# %%
conteudo_pagina = pagina.extract_text()
conteudo_pagina
# Out:
# ' \nRepública da Polónia / Polônia \nRzeczpospolita Polska\nBandeira Brasão de armas\nHino nacional: Mazurek Dąbrowskiego \n("Mazurca de Dąbrowski")\nGentílico: Polaco ou polonês\n \n \nLocalização da Polônia (em verde escuro) na\nUnião Europeia (em verde claro) \nCapital Varsóvia  \n52°13′N 21°02′E\nCidade mais\npopulosaVarsóviaPolónia\nOrigem: Wikipédia, a enciclopédia livre.\nPolónia (português europeu) ou Polônia (português\nbrasileiro) (em polonês/polaco: Polska,\npronunciado: [ˈpɔlska] (\nescutar )),\noficialmente República da Polónia (em\npolonês/polaco: Rzeczpospolita Polska,\npronunciado: [ʐɛt͡ʂpɔˈspɔʎit̪a ˈpɔlska]\n(\nescutar )), é um país da Europa Central que\ntem fronteiras comuns com a Alemanha a oeste;\ncom a Chéquia e a Eslováquia ao sul; com a\nUcrânia e a Bielorrússia a leste; com o Mar\nBáltico, o Oblast de Kaliningrado (um exclave\nrusso) e a Lituânia ao norte. A área total da\nnação é 312 679 quilômetros quadrados,[5] o\nque a torna o 69.º maior país do mundo  e o 9.º\nmaior da Europa. Com uma popul ação de mais\nde 38,5 milhões de pessoas,[5] a Polônia é o\n34.º país mais popu loso do mundo ,[6] o sexto\nmembro mais popul oso da União Europeia\n(UE) e o Estado pós-comunista mais popul oso\nda UE. A Polônia é um Estado unitário\ndividido em 16 voivodias (subdivisões\nadministrativas).[5]\nMuitos historiadores traçam o estabelecimento\ndo Estado polonês em 966, quando Mieszko\nI,[7] governante de um território mais ou menos\ncom a mesma extensão que o da atual Polônia,\nse converteu ao catolicismo. O Reino da\nPolônia foi funda do em 1025 e em 1569\ncimentou uma associação política de longa  data\ncom o Grão-Ducado da Lituânia, assinando a\nUnião de Lublin, que acabou por formar a\nComunidade Polaco-Lituana. A Comunidade\ngradualmente deixou de existir nos anos 1772-\n1795, quando o território polaco foi dividido\nentre o Reino da Prússia, o Império Russo e a\nÁustria. A Polônia recuperou sua\nindependência (como a Segunda  República\nPolonesa), no final da Primeira Guerra\nMundial, em 1918.\n0:000:00\n/ 0:00/ 0:00\n'
